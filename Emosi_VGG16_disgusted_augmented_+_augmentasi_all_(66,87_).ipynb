# %% [markdown]
# <a href="https://colab.research.google.com/github/widyamelia26/Facial-Emotion-Recognition/blob/main/Emosi_VGG16_disgusted_augmented_%2B_augmentasi_all_(66%2C87_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
#
# # Hapus file/direktori jika sudah ada sebelumnya
# if test -e "fer-augmented.zip" || test -e "emotion-detection-fer.zip"; then
#     rm -rf fer-augmented.zip emotion-detection-fer.zip ./train ./test
# fi
#
# # Download dataset train and unzip to ./train
# kaggle datasets download -d retr0desk/fer-augmented -p ./ --unzip
#
#
# # Ubah nama kelas "disgusted_augmented" menjadi "disgusted" pada dataset train
# if [ -d "/content/emotion_detection_augmentasi/train/disgusted_augmented" ]; then
#     mv /content/emotion_detection_augmentasi/train/disgusted_augmented /content/emotion_detection_augmentasi/train/disgusted
# fi
#
# # Download dataset test
# kaggle datasets download -d ananthu017/emotion-detection-fer -p ./ --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/retr0desk/fer-augmented
# License(s): apache-2.0
# Downloading fer-augmented.zip to .
#
# Dataset URL: https://www.kaggle.com/datasets/ananthu017/emotion-detection-fer
# License(s): CC0-1.0
# Downloading emotion-detection-fer.zip to .
# 100%|██████████| 64.9M/64.9M [00:01<00:00, 59.0MB/s]
# 100%|██████████| 65.2M/65.2M [00:00<00:00, 133MB/s]

# %%
import glob

import matplotlib.pyplot as plt
import seaborn as sns


train_path = "/content/emotion_detection_augmentasi/train"
test_path = "/content/test"
class_names = ["angry", "disgusted", "fearful", "happy", "neutral", "sad", "surprised"]
class_distribution = {}

# Put image paths to dictionary using class names as keys.
for class_name in class_names:
    class_distribution[class_name] = len(glob.glob(f"{train_path}/{class_name}/*"))

plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")
sns.barplot(x=list(class_distribution.keys()), y=list(class_distribution.values()))

plt.title("Class Distribution", fontsize=16)
plt.xlabel("Classes", fontsize=12)
plt.ylabel("Total Images", fontsize=12)
plt.xticks(rotation=45)

# Add value labels of each bar.
for index, value in enumerate(class_distribution.values()):
    plt.text(index, value, str(value), ha="center", fontsize=10)

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np


def plot_sample_images():
    fig, axis = plt.subplots(1, 7, figsize=[13, 15])

    for index, (class_name, count) in enumerate(class_distribution.items()):
        # Randomly choose images to plot.
        random_index = np.random.randint(0, count)
        img_read = cv2.imread(
            glob.glob(f"{train_path}/{class_name}/*")[random_index]
        )

        axis[index].imshow(img_read)
        axis[index].set_title(class_name)

# Plot several samples of each class.
for i in range(0, 3):
    plot_sample_images()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


# Data generator for traning and validation.
train_data_generator = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2 # 20% of images to be used for validation.
)

train_generator = train_data_generator.flow_from_directory(
    train_path,
    target_size=(64, 64),
    batch_size=16,
    class_mode="categorical",
    subset="training",
)

validation_generator = train_data_generator.flow_from_directory(
    train_path,
    target_size=(64, 64),
    batch_size=16,
    class_mode="categorical",
    subset="validation",
)
# Out:
# Found 30619 images belonging to 7 classes.
# Found 7654 images belonging to 7 classes.

# %%
# Data generator for evaluation.
test_data_generator = ImageDataGenerator(rescale=1./255)
test_generator = test_data_generator.flow_from_directory(
    test_path,
    target_size=(64, 64),
    batch_size=16,
    class_mode="categorical",
    shuffle = False  # Keep this False for confusion matrix.
)
# Out:
# Found 7178 images belonging to 7 classes.

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.regularizers import l2

def create_pretrained_model(input_shape):
    # Load VGG16
    base_model = VGG16(weights='imagenet',
                       include_top=False,
                       input_shape=input_shape)

    # Unfreeze beberapa layer terakhir untuk fine-tuning
    for layer in base_model.layers[:-4]:
        layer.trainable = False
    for layer in base_model.layers[-4:]:
        layer.trainable = True

    return base_model

base_model = create_pretrained_model((64, 64, 3))

def create_model(input_shape=(64, 64, 3)):
    # Base model
    base_model = create_pretrained_model(input_shape)

    # Custom layers dengan arsitektur yang dioptimalkan
    x = base_model.output

    # Additional convolutional blocks untuk feature extraction
    # First Convolutional Block
    x = Conv2D(64, kernel_size=3, padding='same', activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    x = Conv2D(64, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    # Second Convolutional Block
    x = Conv2D(128, kernel_size=3, padding='same', activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    x = Conv2D(128, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2), padding='same')(x)

    # Third Convolutional Block
    x = Conv2D(256, kernel_size=3, padding='same', activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    x = Conv2D(256, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2), padding='same')(x)

    # Flatten and Fully Connected Layers
    x = Flatten()(x)
    x = Dense(4096, activation = 'relu', kernel_regularizer=l2(0.01))(x)
    x = Dropout(0.5)(x)
    x = Dense(1024, activation = 'relu', kernel_regularizer=l2(0.01))(x)
    x = Dropout(0.5)(x)

    # Output layer
    predictions = Dense(7, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)
    return model

# Buat model
model = create_model()
model.summary()
# Gambar flowchart dari model
plot_model(model, to_file='cnn_model.png', show_shapes=True, show_layer_names=True)

# Menampilkan flowchart dalam notebook
img = plt.imread('cnn_model.png')
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 64, 64, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 64, 64, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 64, 64, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 32, 32, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 32, 32, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 16, 16, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 16, 16, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 16, 16, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 8, 8, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 8, 8, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 8, 8, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 4, 4, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 4, 4, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 4, 4, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 2, 2, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 2, 2, 64)            │         294,976 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 2, 2, 64)            │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 2, 2, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 2, 2, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 1, 1, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 1, 1, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 1, 1, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 1, 1, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 1, 1, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 1, 1, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 1, 1, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 1, 1, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 1, 1, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 4096)                │       1,052,672 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1024)                │       4,195,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 7)                   │           7,175 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 21,410,247 (81.67 MB)
#  Trainable params: 13,774,087 (52.54 MB)
#  Non-trainable params: 7,636,160 (29.13 MB)

# %%
import tensorflow as tf
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau


model.compile(
    optimizer=SGD(learning_rate=0.001, momentum=0.9, weight_decay=1e-4),
    loss=categorical_crossentropy,
    metrics=["accuracy", "auc"]
)

# Define callbacks.
early_stopping = EarlyStopping(monitor="val_loss", patience=15, restore_best_weights=True,verbose=1)
checkpoint = ModelCheckpoint("emotion_detection_model.keras", monitor="val_accuracy", save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-7, verbose=1)

# Train the model.
history = model.fit(
    train_generator,
    epochs=80,
    validation_data=validation_generator,
    callbacks=[early_stopping, checkpoint, reduce_lr]
    )

# Determine at which epoch early stopping occurred
stopped_epoch = len(history.history['accuracy'])
print(f"Training stopped at epoch: {stopped_epoch}")
# Out:
# Epoch 1/80
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3522 - auc: 0.7119 - loss: 19.4724
# Epoch 1: val_accuracy improved from -inf to 0.45571, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 114s 53ms/step - accuracy: 0.3523 - auc: 0.7119 - loss: 19.4692 - val_accuracy: 0.4557 - val_auc: 0.8185 - val_loss: 11.2677 - learning_rate: 0.0010
# Epoch 2/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4749 - auc: 0.8262 - loss: 9.6336
# Epoch 2: val_accuracy improved from 0.45571 to 0.50000, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 92s 48ms/step - accuracy: 0.4749 - auc: 0.8262 - loss: 9.6321 - val_accuracy: 0.5000 - val_auc: 0.8524 - val_loss: 5.8685 - learning_rate: 0.0010
# Epoch 3/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5263 - auc: 0.8622 - loss: 5.0861
# Epoch 3: val_accuracy improved from 0.50000 to 0.54155, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 141s 47ms/step - accuracy: 0.5263 - auc: 0.8622 - loss: 5.0854 - val_accuracy: 0.5415 - val_auc: 0.8753 - val_loss: 3.3278 - learning_rate: 0.0010
# Epoch 4/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5412 - auc: 0.8738 - loss: 2.9772
# Epoch 4: val_accuracy improved from 0.54155 to 0.56154, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 138s 45ms/step - accuracy: 0.5412 - auc: 0.8738 - loss: 2.9769 - val_accuracy: 0.5615 - val_auc: 0.8864 - val_loss: 2.1322 - learning_rate: 0.0010
# Epoch 5/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5538 - auc: 0.8805 - loss: 1.9990
# Epoch 5: val_accuracy improved from 0.56154 to 0.56885, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 140s 44ms/step - accuracy: 0.5538 - auc: 0.8805 - loss: 1.9989 - val_accuracy: 0.5689 - val_auc: 0.8899 - val_loss: 1.5896 - learning_rate: 0.0010
# Epoch 6/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5692 - auc: 0.8893 - loss: 1.5168
# Epoch 6: val_accuracy improved from 0.56885 to 0.57983, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 87s 45ms/step - accuracy: 0.5692 - auc: 0.8893 - loss: 1.5168 - val_accuracy: 0.5798 - val_auc: 0.8955 - val_loss: 1.3187 - learning_rate: 0.0010
# Epoch 7/80
# 1912/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5770 - auc: 0.8931 - loss: 1.2963
# Epoch 7: val_accuracy improved from 0.57983 to 0.59394, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 85s 44ms/step - accuracy: 0.5770 - auc: 0.8931 - loss: 1.2962 - val_accuracy: 0.5939 - val_auc: 0.9011 - val_loss: 1.1792 - learning_rate: 0.0010
# Epoch 8/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5798 - auc: 0.8950 - loss: 1.1932
# Epoch 8: val_accuracy did not improve from 0.59394
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 85s 44ms/step - accuracy: 0.5798 - auc: 0.8950 - loss: 1.1932 - val_accuracy: 0.5932 - val_auc: 0.9031 - val_loss: 1.1107 - learning_rate: 0.0010
# Epoch 9/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5940 - auc: 0.9020 - loss: 1.1162
# Epoch 9: val_accuracy did not improve from 0.59394
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 85s 44ms/step - accuracy: 0.5940 - auc: 0.9020 - loss: 1.1162 - val_accuracy: 0.5888 - val_auc: 0.9012 - val_loss: 1.1059 - learning_rate: 0.0010
# Epoch 10/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5998 - auc: 0.9051 - loss: 1.0800
# Epoch 10: val_accuracy did not improve from 0.59394
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 85s 44ms/step - accuracy: 0.5998 - auc: 0.9051 - loss: 1.0800 - val_accuracy: 0.5790 - val_auc: 0.8978 - val_loss: 1.0981 - learning_rate: 0.0010
# Epoch 11/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5912 - auc: 0.9015 - loss: 1.0879
# Epoch 11: val_accuracy improved from 0.59394 to 0.59668, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 91s 47ms/step - accuracy: 0.5912 - auc: 0.9015 - loss: 1.0879 - val_accuracy: 0.5967 - val_auc: 0.9058 - val_loss: 1.0607 - learning_rate: 0.0010
# Epoch 12/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6041 - auc: 0.9082 - loss: 1.0503
# Epoch 12: val_accuracy did not improve from 0.59668
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 91s 47ms/step - accuracy: 0.6041 - auc: 0.9082 - loss: 1.0503 - val_accuracy: 0.5839 - val_auc: 0.8976 - val_loss: 1.0989 - learning_rate: 0.0010
# Epoch 13/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6080 - auc: 0.9109 - loss: 1.0335
# Epoch 13: val_accuracy improved from 0.59668 to 0.60348, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 91s 47ms/step - accuracy: 0.6080 - auc: 0.9109 - loss: 1.0335 - val_accuracy: 0.6035 - val_auc: 0.9107 - val_loss: 1.0322 - learning_rate: 0.0010
# Epoch 14/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6058 - auc: 0.9100 - loss: 1.0370
# Epoch 14: val_accuracy improved from 0.60348 to 0.61536, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 91s 47ms/step - accuracy: 0.6058 - auc: 0.9100 - loss: 1.0370 - val_accuracy: 0.6154 - val_auc: 0.9136 - val_loss: 1.0142 - learning_rate: 0.0010
# Epoch 15/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6134 - auc: 0.9131 - loss: 1.0210
# Epoch 15: val_accuracy did not improve from 0.61536
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 141s 47ms/step - accuracy: 0.6134 - auc: 0.9131 - loss: 1.0210 - val_accuracy: 0.6062 - val_auc: 0.9113 - val_loss: 1.0250 - learning_rate: 0.0010
# Epoch 16/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6215 - auc: 0.9149 - loss: 1.0126
# Epoch 16: val_accuracy did not improve from 0.61536
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 85s 44ms/step - accuracy: 0.6215 - auc: 0.9149 - loss: 1.0126 - val_accuracy: 0.5916 - val_auc: 0.9051 - val_loss: 1.0604 - learning_rate: 0.0010
# Epoch 17/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6187 - auc: 0.9143 - loss: 1.0148
# Epoch 17: val_accuracy did not improve from 0.61536
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 142s 44ms/step - accuracy: 0.6187 - auc: 0.9143 - loss: 1.0148 - val_accuracy: 0.6137 - val_auc: 0.9150 - val_loss: 1.0081 - learning_rate: 0.0010
# Epoch 18/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6273 - auc: 0.9182 - loss: 0.9950
# Epoch 18: val_accuracy improved from 0.61536 to 0.62569, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 150s 49ms/step - accuracy: 0.6273 - auc: 0.9182 - loss: 0.9950 - val_accuracy: 0.6257 - val_auc: 0.9182 - val_loss: 0.9901 - learning_rate: 0.0010
# Epoch 19/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6267 - auc: 0.9184 - loss: 0.9923
# Epoch 19: val_accuracy did not improve from 0.62569
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 133s 44ms/step - accuracy: 0.6267 - auc: 0.9184 - loss: 0.9923 - val_accuracy: 0.6120 - val_auc: 0.9154 - val_loss: 1.0065 - learning_rate: 0.0010
# Epoch 20/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6339 - auc: 0.9205 - loss: 0.9836
# Epoch 20: val_accuracy did not improve from 0.62569
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 86s 45ms/step - accuracy: 0.6339 - auc: 0.9205 - loss: 0.9836 - val_accuracy: 0.6207 - val_auc: 0.9173 - val_loss: 0.9953 - learning_rate: 0.0010
# Epoch 21/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6355 - auc: 0.9215 - loss: 0.9765
# Epoch 21: val_accuracy improved from 0.62569 to 0.63078, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 91s 48ms/step - accuracy: 0.6355 - auc: 0.9215 - loss: 0.9765 - val_accuracy: 0.6308 - val_auc: 0.9203 - val_loss: 0.9826 - learning_rate: 0.0010
# Epoch 22/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6392 - auc: 0.9232 - loss: 0.9662
# Epoch 22: val_accuracy did not improve from 0.63078
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 84s 44ms/step - accuracy: 0.6392 - auc: 0.9232 - loss: 0.9662 - val_accuracy: 0.6015 - val_auc: 0.9082 - val_loss: 1.0511 - learning_rate: 0.0010
# Epoch 23/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6368 - auc: 0.9222 - loss: 0.9728
# Epoch 23: val_accuracy did not improve from 0.63078
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 86s 45ms/step - accuracy: 0.6368 - auc: 0.9222 - loss: 0.9728 - val_accuracy: 0.6267 - val_auc: 0.9189 - val_loss: 0.9897 - learning_rate: 0.0010
# Epoch 24/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6457 - auc: 0.9248 - loss: 0.9579
# Epoch 24: val_accuracy did not improve from 0.63078
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 148s 48ms/step - accuracy: 0.6457 - auc: 0.9248 - loss: 0.9579 - val_accuracy: 0.6233 - val_auc: 0.9175 - val_loss: 0.9982 - learning_rate: 0.0010
# Epoch 25/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6393 - auc: 0.9232 - loss: 0.9665
# Epoch 25: val_accuracy improved from 0.63078 to 0.63836, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 91s 47ms/step - accuracy: 0.6393 - auc: 0.9232 - loss: 0.9665 - val_accuracy: 0.6384 - val_auc: 0.9218 - val_loss: 0.9729 - learning_rate: 0.0010
# Epoch 26/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6481 - auc: 0.9260 - loss: 0.9502
# Epoch 26: val_accuracy improved from 0.63836 to 0.64097, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 94s 49ms/step - accuracy: 0.6481 - auc: 0.9260 - loss: 0.9502 - val_accuracy: 0.6410 - val_auc: 0.9233 - val_loss: 0.9643 - learning_rate: 0.0010
# Epoch 27/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6504 - auc: 0.9266 - loss: 0.9466
# Epoch 27: val_accuracy did not improve from 0.64097
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 93s 48ms/step - accuracy: 0.6504 - auc: 0.9266 - loss: 0.9466 - val_accuracy: 0.6220 - val_auc: 0.9178 - val_loss: 0.9888 - learning_rate: 0.0010
# Epoch 28/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6485 - auc: 0.9268 - loss: 0.9454
# Epoch 28: val_accuracy did not improve from 0.64097
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 90s 47ms/step - accuracy: 0.6485 - auc: 0.9268 - loss: 0.9454 - val_accuracy: 0.6244 - val_auc: 0.9184 - val_loss: 1.0001 - learning_rate: 0.0010
# Epoch 29/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6553 - auc: 0.9289 - loss: 0.9340
# Epoch 29: val_accuracy did not improve from 0.64097
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 87s 45ms/step - accuracy: 0.6553 - auc: 0.9289 - loss: 0.9340 - val_accuracy: 0.6393 - val_auc: 0.9244 - val_loss: 0.9584 - learning_rate: 0.0010
# Epoch 30/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6615 - auc: 0.9317 - loss: 0.9169
# Epoch 30: val_accuracy did not improve from 0.64097
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 93s 48ms/step - accuracy: 0.6615 - auc: 0.9317 - loss: 0.9169 - val_accuracy: 0.6384 - val_auc: 0.9230 - val_loss: 0.9676 - learning_rate: 0.0010
# Epoch 31/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6605 - auc: 0.9300 - loss: 0.9268
# Epoch 31: val_accuracy did not improve from 0.64097
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 93s 48ms/step - accuracy: 0.6605 - auc: 0.9300 - loss: 0.9268 - val_accuracy: 0.6265 - val_auc: 0.9193 - val_loss: 0.9826 - learning_rate: 0.0010
# Epoch 32/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6523 - auc: 0.9273 - loss: 0.9440
# Epoch 32: val_accuracy did not improve from 0.64097
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 142s 48ms/step - accuracy: 0.6523 - auc: 0.9273 - loss: 0.9440 - val_accuracy: 0.6348 - val_auc: 0.9223 - val_loss: 0.9705 - learning_rate: 0.0010
# Epoch 33/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6544 - auc: 0.9304 - loss: 0.9253
# Epoch 33: val_accuracy did not improve from 0.64097
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 135s 45ms/step - accuracy: 0.6544 - auc: 0.9304 - loss: 0.9253 - val_accuracy: 0.6338 - val_auc: 0.9217 - val_loss: 0.9761 - learning_rate: 0.0010
# Epoch 34/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6564 - auc: 0.9302 - loss: 0.9259
# Epoch 34: val_accuracy did not improve from 0.64097
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 143s 45ms/step - accuracy: 0.6564 - auc: 0.9302 - loss: 0.9259 - val_accuracy: 0.6386 - val_auc: 0.9245 - val_loss: 0.9590 - learning_rate: 0.0010
# Epoch 35/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6731 - auc: 0.9373 - loss: 0.8824
# Epoch 35: val_accuracy improved from 0.64097 to 0.64672, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 141s 45ms/step - accuracy: 0.6731 - auc: 0.9373 - loss: 0.8824 - val_accuracy: 0.6467 - val_auc: 0.9295 - val_loss: 0.9299 - learning_rate: 1.0000e-04
# Epoch 36/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6812 - auc: 0.9403 - loss: 0.8628
# Epoch 36: val_accuracy improved from 0.64672 to 0.65182, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 93s 49ms/step - accuracy: 0.6812 - auc: 0.9403 - loss: 0.8628 - val_accuracy: 0.6518 - val_auc: 0.9298 - val_loss: 0.9252 - learning_rate: 1.0000e-04
# Epoch 37/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6835 - auc: 0.9408 - loss: 0.8575
# Epoch 37: val_accuracy improved from 0.65182 to 0.65796, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 86s 45ms/step - accuracy: 0.6835 - auc: 0.9408 - loss: 0.8575 - val_accuracy: 0.6580 - val_auc: 0.9311 - val_loss: 0.9172 - learning_rate: 1.0000e-04
# Epoch 38/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6912 - auc: 0.9427 - loss: 0.8440
# Epoch 38: val_accuracy did not improve from 0.65796
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 85s 45ms/step - accuracy: 0.6912 - auc: 0.9427 - loss: 0.8440 - val_accuracy: 0.6543 - val_auc: 0.9317 - val_loss: 0.9133 - learning_rate: 1.0000e-04
# Epoch 39/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6901 - auc: 0.9423 - loss: 0.8463
# Epoch 39: val_accuracy improved from 0.65796 to 0.66371, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 146s 47ms/step - accuracy: 0.6901 - auc: 0.9423 - loss: 0.8463 - val_accuracy: 0.6637 - val_auc: 0.9324 - val_loss: 0.9084 - learning_rate: 1.0000e-04
# Epoch 40/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6964 - auc: 0.9430 - loss: 0.8406
# Epoch 40: val_accuracy did not improve from 0.66371
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 89s 46ms/step - accuracy: 0.6964 - auc: 0.9430 - loss: 0.8406 - val_accuracy: 0.6556 - val_auc: 0.9296 - val_loss: 0.9264 - learning_rate: 1.0000e-04
# Epoch 41/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6967 - auc: 0.9448 - loss: 0.8281
# Epoch 41: val_accuracy did not improve from 0.66371
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 93s 48ms/step - accuracy: 0.6967 - auc: 0.9448 - loss: 0.8281 - val_accuracy: 0.6607 - val_auc: 0.9311 - val_loss: 0.9156 - learning_rate: 1.0000e-04
# Epoch 42/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7008 - auc: 0.9453 - loss: 0.8242
# Epoch 42: val_accuracy did not improve from 0.66371
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 92s 48ms/step - accuracy: 0.7008 - auc: 0.9453 - loss: 0.8242 - val_accuracy: 0.6539 - val_auc: 0.9310 - val_loss: 0.9183 - learning_rate: 1.0000e-04
# Epoch 43/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6912 - auc: 0.9430 - loss: 0.8386
# Epoch 43: val_accuracy did not improve from 0.66371
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 88s 46ms/step - accuracy: 0.6912 - auc: 0.9430 - loss: 0.8386 - val_accuracy: 0.6616 - val_auc: 0.9323 - val_loss: 0.9073 - learning_rate: 1.0000e-04
# Epoch 44/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6981 - auc: 0.9451 - loss: 0.8244
# Epoch 44: val_accuracy did not improve from 0.66371
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 94s 49ms/step - accuracy: 0.6981 - auc: 0.9451 - loss: 0.8244 - val_accuracy: 0.6555 - val_auc: 0.9301 - val_loss: 0.9200 - learning_rate: 1.0000e-04
# Epoch 45/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6959 - auc: 0.9437 - loss: 0.8326
# Epoch 45: val_accuracy did not improve from 0.66371
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 136s 46ms/step - accuracy: 0.6959 - auc: 0.9437 - loss: 0.8326 - val_accuracy: 0.6543 - val_auc: 0.9312 - val_loss: 0.9151 - learning_rate: 1.0000e-04
# Epoch 46/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7004 - auc: 0.9454 - loss: 0.8207
# Epoch 46: val_accuracy did not improve from 0.66371
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 142s 46ms/step - accuracy: 0.7004 - auc: 0.9454 - loss: 0.8207 - val_accuracy: 0.6608 - val_auc: 0.9323 - val_loss: 0.9077 - learning_rate: 1.0000e-04
# Epoch 47/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7028 - auc: 0.9457 - loss: 0.8188
# Epoch 47: val_accuracy did not improve from 0.66371
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 86s 45ms/step - accuracy: 0.7028 - auc: 0.9457 - loss: 0.8188 - val_accuracy: 0.6565 - val_auc: 0.9311 - val_loss: 0.9143 - learning_rate: 1.0000e-04
# Epoch 48/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7052 - auc: 0.9465 - loss: 0.8123
# Epoch 48: val_accuracy did not improve from 0.66371
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 144s 46ms/step - accuracy: 0.7052 - auc: 0.9465 - loss: 0.8123 - val_accuracy: 0.6536 - val_auc: 0.9326 - val_loss: 0.9041 - learning_rate: 1.0000e-04
# Epoch 49/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7065 - auc: 0.9464 - loss: 0.8140
# Epoch 49: val_accuracy did not improve from 0.66371
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 145s 48ms/step - accuracy: 0.7065 - auc: 0.9464 - loss: 0.8140 - val_accuracy: 0.6608 - val_auc: 0.9315 - val_loss: 0.9096 - learning_rate: 1.0000e-04
# Epoch 50/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7027 - auc: 0.9456 - loss: 0.8192
# Epoch 50: val_accuracy did not improve from 0.66371
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 143s 48ms/step - accuracy: 0.7027 - auc: 0.9456 - loss: 0.8192 - val_accuracy: 0.6580 - val_auc: 0.9318 - val_loss: 0.9095 - learning_rate: 1.0000e-04
# Epoch 51/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7038 - auc: 0.9470 - loss: 0.8090
# Epoch 51: val_accuracy did not improve from 0.66371
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 93s 48ms/step - accuracy: 0.7038 - auc: 0.9470 - loss: 0.8090 - val_accuracy: 0.6602 - val_auc: 0.9313 - val_loss: 0.9114 - learning_rate: 1.0000e-04
# Epoch 52/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7044 - auc: 0.9476 - loss: 0.8045
# Epoch 52: val_accuracy did not improve from 0.66371
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 93s 48ms/step - accuracy: 0.7044 - auc: 0.9476 - loss: 0.8045 - val_accuracy: 0.6619 - val_auc: 0.9316 - val_loss: 0.9136 - learning_rate: 1.0000e-04
# Epoch 53/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7087 - auc: 0.9475 - loss: 0.8043
# Epoch 53: val_accuracy did not improve from 0.66371
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 86s 45ms/step - accuracy: 0.7087 - auc: 0.9475 - loss: 0.8043 - val_accuracy: 0.6616 - val_auc: 0.9316 - val_loss: 0.9099 - learning_rate: 1.0000e-04
# Epoch 54/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7111 - auc: 0.9484 - loss: 0.7980
# Epoch 54: val_accuracy did not improve from 0.66371
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 92s 48ms/step - accuracy: 0.7111 - auc: 0.9484 - loss: 0.7980 - val_accuracy: 0.6585 - val_auc: 0.9323 - val_loss: 0.9058 - learning_rate: 1.0000e-05
# Epoch 55/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7078 - auc: 0.9492 - loss: 0.7940
# Epoch 55: val_accuracy improved from 0.66371 to 0.66710, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 143s 49ms/step - accuracy: 0.7078 - auc: 0.9492 - loss: 0.7940 - val_accuracy: 0.6671 - val_auc: 0.9338 - val_loss: 0.8973 - learning_rate: 1.0000e-05
# Epoch 56/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7134 - auc: 0.9488 - loss: 0.7961
# Epoch 56: val_accuracy did not improve from 0.66710
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 93s 49ms/step - accuracy: 0.7134 - auc: 0.9488 - loss: 0.7961 - val_accuracy: 0.6634 - val_auc: 0.9331 - val_loss: 0.9015 - learning_rate: 1.0000e-05
# Epoch 57/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7102 - auc: 0.9476 - loss: 0.8036
# Epoch 57: val_accuracy did not improve from 0.66710
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 87s 46ms/step - accuracy: 0.7102 - auc: 0.9476 - loss: 0.8036 - val_accuracy: 0.6642 - val_auc: 0.9329 - val_loss: 0.9027 - learning_rate: 1.0000e-05
# Epoch 58/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7089 - auc: 0.9483 - loss: 0.7985
# Epoch 58: val_accuracy did not improve from 0.66710
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 148s 48ms/step - accuracy: 0.7089 - auc: 0.9483 - loss: 0.7985 - val_accuracy: 0.6637 - val_auc: 0.9330 - val_loss: 0.9021 - learning_rate: 1.0000e-05
# Epoch 59/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7086 - auc: 0.9471 - loss: 0.8075
# Epoch 59: val_accuracy did not improve from 0.66710
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 92s 48ms/step - accuracy: 0.7086 - auc: 0.9471 - loss: 0.8075 - val_accuracy: 0.6598 - val_auc: 0.9319 - val_loss: 0.9084 - learning_rate: 1.0000e-05
# Epoch 60/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7135 - auc: 0.9496 - loss: 0.7899
# Epoch 60: val_accuracy did not improve from 0.66710
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 92s 48ms/step - accuracy: 0.7135 - auc: 0.9496 - loss: 0.7899 - val_accuracy: 0.6653 - val_auc: 0.9344 - val_loss: 0.8942 - learning_rate: 1.0000e-05
# Epoch 61/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7092 - auc: 0.9490 - loss: 0.7939
# Epoch 61: val_accuracy did not improve from 0.66710
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 142s 48ms/step - accuracy: 0.7092 - auc: 0.9490 - loss: 0.7939 - val_accuracy: 0.6598 - val_auc: 0.9317 - val_loss: 0.9105 - learning_rate: 1.0000e-05
# Epoch 62/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7115 - auc: 0.9485 - loss: 0.7969
# Epoch 62: val_accuracy did not improve from 0.66710
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 93s 48ms/step - accuracy: 0.7115 - auc: 0.9485 - loss: 0.7969 - val_accuracy: 0.6644 - val_auc: 0.9337 - val_loss: 0.8982 - learning_rate: 1.0000e-05
# Epoch 63/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7148 - auc: 0.9504 - loss: 0.7839
# Epoch 63: val_accuracy did not improve from 0.66710
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 93s 48ms/step - accuracy: 0.7148 - auc: 0.9504 - loss: 0.7839 - val_accuracy: 0.6666 - val_auc: 0.9341 - val_loss: 0.8954 - learning_rate: 1.0000e-05
# Epoch 64/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7130 - auc: 0.9496 - loss: 0.7891
# Epoch 64: val_accuracy did not improve from 0.66710
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 87s 45ms/step - accuracy: 0.7130 - auc: 0.9496 - loss: 0.7891 - val_accuracy: 0.6616 - val_auc: 0.9336 - val_loss: 0.8969 - learning_rate: 1.0000e-05
# Epoch 65/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7093 - auc: 0.9491 - loss: 0.7938
# Epoch 65: val_accuracy did not improve from 0.66710
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 85s 44ms/step - accuracy: 0.7093 - auc: 0.9491 - loss: 0.7938 - val_accuracy: 0.6587 - val_auc: 0.9321 - val_loss: 0.9084 - learning_rate: 1.0000e-05
# Epoch 66/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7068 - auc: 0.9490 - loss: 0.7936
# Epoch 66: val_accuracy improved from 0.66710 to 0.66867, saving model to emotion_detection_model.keras
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 144s 46ms/step - accuracy: 0.7068 - auc: 0.9490 - loss: 0.7936 - val_accuracy: 0.6687 - val_auc: 0.9335 - val_loss: 0.8998 - learning_rate: 1.0000e-06
# Epoch 67/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7123 - auc: 0.9502 - loss: 0.7846
# Epoch 67: val_accuracy did not improve from 0.66867
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 140s 45ms/step - accuracy: 0.7123 - auc: 0.9502 - loss: 0.7846 - val_accuracy: 0.6645 - val_auc: 0.9335 - val_loss: 0.8994 - learning_rate: 1.0000e-06
# Epoch 68/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7150 - auc: 0.9499 - loss: 0.7875
# Epoch 68: val_accuracy did not improve from 0.66867
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 142s 45ms/step - accuracy: 0.7150 - auc: 0.9499 - loss: 0.7875 - val_accuracy: 0.6674 - val_auc: 0.9324 - val_loss: 0.9059 - learning_rate: 1.0000e-06
# Epoch 69/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7143 - auc: 0.9499 - loss: 0.7874
# Epoch 69: val_accuracy did not improve from 0.66867
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 148s 48ms/step - accuracy: 0.7143 - auc: 0.9499 - loss: 0.7874 - val_accuracy: 0.6649 - val_auc: 0.9309 - val_loss: 0.9166 - learning_rate: 1.0000e-06
# Epoch 70/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7148 - auc: 0.9500 - loss: 0.7872
# Epoch 70: val_accuracy did not improve from 0.66867
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 87s 45ms/step - accuracy: 0.7148 - auc: 0.9500 - loss: 0.7872 - val_accuracy: 0.6593 - val_auc: 0.9314 - val_loss: 0.9131 - learning_rate: 1.0000e-06
# Epoch 71/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7131 - auc: 0.9492 - loss: 0.7930
# Epoch 71: val_accuracy did not improve from 0.66867
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 142s 45ms/step - accuracy: 0.7131 - auc: 0.9492 - loss: 0.7930 - val_accuracy: 0.6611 - val_auc: 0.9333 - val_loss: 0.8996 - learning_rate: 1.0000e-07
# Epoch 72/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7138 - auc: 0.9498 - loss: 0.7881
# Epoch 72: val_accuracy did not improve from 0.66867
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 95s 49ms/step - accuracy: 0.7138 - auc: 0.9498 - loss: 0.7881 - val_accuracy: 0.6637 - val_auc: 0.9312 - val_loss: 0.9153 - learning_rate: 1.0000e-07
# Epoch 73/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7119 - auc: 0.9498 - loss: 0.7879
# Epoch 73: val_accuracy did not improve from 0.66867
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 134s 45ms/step - accuracy: 0.7119 - auc: 0.9498 - loss: 0.7879 - val_accuracy: 0.6607 - val_auc: 0.9329 - val_loss: 0.9042 - learning_rate: 1.0000e-07
# Epoch 74/80
# 1913/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7130 - auc: 0.9496 - loss: 0.7893
# Epoch 74: val_accuracy did not improve from 0.66867
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 93s 48ms/step - accuracy: 0.7130 - auc: 0.9496 - loss: 0.7893 - val_accuracy: 0.6628 - val_auc: 0.9331 - val_loss: 0.9006 - learning_rate: 1.0000e-07
# Epoch 75/80
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7134 - auc: 0.9495 - loss: 0.7893
# Epoch 75: val_accuracy did not improve from 0.66867
#
# Epoch 75: ReduceLROnPlateau reducing learning rate to 1e-07.
# 1914/1914 ━━━━━━━━━━━━━━━━━━━━ 87s 45ms/step - accuracy: 0.7134 - auc: 0.9495 - loss: 0.7893 - val_accuracy: 0.6658 - val_auc: 0.9332 - val_loss: 0.8999 - learning_rate: 1.0000e-07
# Epoch 75: early stopping
# Restoring model weights from the end of the best epoch: 60.
# Training stopped at epoch: 75

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Nama-nama kelas emosi
class_names = ["angry", "digusted", "fearful", "happy", "neutral", "sad", "surprised"]

# Peroleh true labels dari test generator
true_labels = test_generator.classes

# Reset test generator sebelum prediksi
test_generator.reset()

# Dapatkan prediksi model pada data test
predicted = model.predict(test_generator)
predicted_labels = np.argmax(predicted, axis=1)

# Hitung confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step
